# %% [markdown]
# <a href="https://colab.research.google.com/github/fdominguezd2-unemi/sitio-web/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #verificar si un numero es primo o no

# %%
#verificar si un numero es primo o no       #2-3-5-7-11-13-17-19-23-27-29-31
def is_prime(number)
    if number <=1:
        return False
        if number <=3:
            return True
            if number % 2 == 0 or number % 3 == 0:
                return False
                i = 5
                while i * i <= number:
                    if number % i == 0 or number % ( i + 2) == 0:
                        return False
                        i += 6
                        return True

# %%
#verificar si un numero es primo o no
numero = int(input("introduce un numero"))
if numero <= 1:
    print("no es primo")
else:
    divisor = 2
    es_primo = True

    #probamos todos los numeros desde 2 hasta numero - 1
    while divisor < numero:
        if numero % divisor == 0:
          es_primo= False  # encuentro un divisor , entonces nop es primo
          divisor -divisor + 1 # Sumamos 1 para probar con el siguente numero
          # al final del ciclo , revisamos como quedo nuestra variable
          if es_primo:
            print("Si es primo")
    else:
      print("no es primo")
# Out:
# introduce un numero17
